# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
path = "smile.jpg"

img = plt.imread(path)
plt.imshow(img)
plt.show()

# %%
print(img.min())
print(img.max())
print(img.mean())
# Out:
# 0
# 255
# 183.1447342038341

# %%
np.median(img)
# Out:
# 210.0

# %%
np.average(img)
# Out:
# 183.1447342038341

# %%
np.mean(img)
# Out:
# 183.1447342038341
