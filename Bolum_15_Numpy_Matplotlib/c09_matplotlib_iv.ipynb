# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "coins.jpg"
img = plt.imread(path)

plt.imshow(img)
plt.show()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (474, 640, 3)

# %%
img.ndim
# Out:
# 3

# %%
img.size
# Out:
# 910080

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# rgb--> r =0, g=1, b=2

# %%
print("red channel: ",img[50,50,0]) 
print("green channel: ",img[50,50,1])
print("blue channel: ",img[50,50,2])
print("rgb channel value: ",img[50,50,:])
# Out:
# red channel:  182
# green channel:  162
# blue channel:  111
# rgb channel value:  [182 162 111]
