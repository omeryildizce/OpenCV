# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
y = x
y
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, "o")
plt.show()

# %%
plt.plot(x,y, "o-")
plt.show()

# %%
plt.plot(x,y, "o--")
plt.show()

# %%
plt.plot(x,y, "o--")
plt.plot(x,-y)
plt.show()

# %%
plt.plot(x,y, "o--")
plt.plot(x,-y)
plt.plot(-x,y, "o")
plt.show()

# %%
plt.plot(x,y, "o--")
plt.plot(x,-y)
plt.plot(-x,y, "o")

plt.title("x:y grafiği")
plt.show()
